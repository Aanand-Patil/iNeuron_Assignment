# %%
# Q1.Write a Python program to Extract Unique values dictionary values?

# %%
in_dict = {1:'iron-man',2:'captain-america',3:'ant-man',4:'wasp',5:'iron-man',6:'thanos',7:'thor'}
print(in_dict.values())
print(f'Unique Values: {list(set(in_dict.values()))}')
# Out:
# dict_values(['iron-man', 'captain-america', 'ant-man', 'wasp', 'iron-man', 'thanos', 'thor'])
# Unique Values: ['ant-man', 'thanos', 'wasp', 'iron-man', 'captain-america', 'thor']

# %%
# Q2.Write a Python program to find the sum of all items in a dictionary?

# %%
in_dict = {'maths':95,'sci':70,'bio':80,'phy':78,'eng':60}
print('Sum of All subs: ',sum(in_dict.values()))
# Out:
# Sum of All subs:  383

# %%
# Q3.Write a Python program to Merging two Dictionaries?

# %%
course_details = {
    'cousre_name':'Ineuron'
}
instructors = {
    'course_instructors':['Sudhanshu Kumar','Krish Naik']
}
course_details.update(instructors)
print(course_details)
# Out:
# {'cousre_name': 'Ineuron', 'course_instructors': ['Sudhanshu Kumar', 'Krish Naik']}

# %%
# Q4.Write a Python program to convert key-values list to flat dictionary?

# %%
in_list = [('A',10),('B',20),('C',30),('D',40),('E',50),('F',60),('G',70),('H',80),('I',90),('J',100)]
out_dict = {}
for ele in in_list:
    out_dict[ele[0]] = ele[1]
print(out_dict)
# Out:
# {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50, 'F': 60, 'G': 70, 'H': 80, 'I': 90, 'J': 100}

# %%
# Q5.Write a Python program to insertion at the beginning in OrderedDict?

# %%
from collections import OrderedDict
dict_one = OrderedDict({'Apple':'Iphone','Microsoft':'Windows','Google':'chrome'})
print('dict_one',dict_one)
dict_two = {'Tesla':'SpaceX'}
dict_one.update(dict_two)
print('dict_one',dict_one)
dict_one.move_to_end('Tesla',last=False)
print('dict_one',dict_one)
# Out:
# dict_one OrderedDict([('Apple', 'Iphone'), ('Microsoft', 'Windows'), ('Google', 'chrome')])
# dict_one OrderedDict([('Apple', 'Iphone'), ('Microsoft', 'Windows'), ('Google', 'chrome'), ('Tesla', 'SpaceX')])
# dict_one OrderedDict([('Tesla', 'SpaceX'), ('Apple', 'Iphone'), ('Microsoft', 'Windows'), ('Google', 'chrome')])

# %%
# Q6.Write a Python program to check order of character in string using OrderedDict()?

# %%
from collections import OrderedDict

initial_list = {'a': 1000, 'f': 200, 'd': 300, 'c': 400, 'b': 500, 'e': 600}
print(initial_list)

final_list = OrderedDict(dict(sorted(initial_list.items())))
print(final_list)
# Out:
# {'a': 1000, 'f': 200, 'd': 300, 'c': 400, 'b': 500, 'e': 600}
# OrderedDict([('a', 1000), ('b', 500), ('c', 400), ('d', 300), ('e', 600), ('f', 200)])

# %%
# Q7.Write a Python program to sort Python Dictionaries by Key or Value?

# %%
d_items = {'a':100,'b':22,'c':60,'d':13}

def sort_dict(dict_name,sort_type):
    if sort_type == 'key':
        print(dict(sorted(dict_name.items(), key=lambda x:x[0], reverse=False)))
    else:
        print(dict(sorted(dict_name.items(), key=lambda x:x[1], reverse=False)))
        
sort_dict(d_items,'key')        
sort_dict(d_items,'value')
# Out:
# {'a': 100, 'b': 22, 'c': 60, 'd': 13}
# {'d': 13, 'b': 22, 'c': 60, 'a': 100}

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

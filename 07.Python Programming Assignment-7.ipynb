# %%
# Q1.Write a Python Program to find sum of array?

# %%
import numpy
def sumOfArray():
    my_array = []
    a = int(input("Size of array:"))
    for i in range(a):
        my_array.append(int(input("Element:")))
    my_array = numpy.array(my_array)
    print(f'The sum of {my_array} is {sum(my_array)}')

sumOfArray()
# Out:
# Size of array:3
# Element:1
# Element:2
# Element:3
# The sum of [1 2 3] is 6

# %%
# Q2.Write a Python Program to find largest element in an array?

# %%
def largestElement():
    in_arr = eval(input("Enter the Array: "))
    print(f"The Largest Element in {in_arr} is {sorted(in_arr, reverse=True)[0]}")
    
largestElement()
# Out:
# Enter the Array: [5,6,8,8]
# The Largest Element in [5, 6, 8, 8] is 8

# %%
# Q3.Write a Python Program for array rotation?

# %%
def reverseOfArray():
    in_arr = eval(input("Enter the Array: "))
    print(f"The Reverse of Array {in_arr} is {in_arr[::-1]}")
    
reverseOfArray()
# Out:
# Enter the Array: [45,5445,4554,45,54]
# The Reverse of Array [45, 5445, 4554, 45, 54] is [54, 45, 4554, 5445, 45]

# %%
# Q4.Write a Python Program to Split the array and add the first part to the end?

# %%
def sumOfSplits():
    in_arr = eval(input("Enter the Array: "))
    print(f"The Sum of First and Last Elements of Array {in_arr} is {in_arr[0]+in_arr[-1]}")
    
sumOfSplits()
# Out:
# Enter the Array: [45,4,54,4,21,1]
# The Sum of First and Last Elements of Array [45, 4, 54, 4, 21, 1] is 46

# %%
# Q5.Write a Python Program to check if given array is Monotonic?

# %%
def checkMonotonic():
    in_arr = eval(input("Enter the Array: "))
    if(all(in_arr[i]<=in_arr[i+1] for i in range(len(in_arr)-1)) or all(in_arr[i]>=in_arr[i+1] for i in range(len(in_arr)-1))):
        print(f'Array {in_arr} is Monotonic')
    else:
        print(f'Array {in_arr} is Not Monotonic')

checkMonotonic()
# Out:
# Enter the Array: [56,56,23,89]
# Array [56, 56, 23, 89] is Not Monotonic

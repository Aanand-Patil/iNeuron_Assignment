# %% [markdown]
# # Q1

# %% [markdown]
# (1.) How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# Ans:
#
# * "shutil.copy()" will copy a single file.
# * "shutil.copytree()" will copy an entire folder and every folder and file contained in it.

# %% [markdown]
# # Q2

# %% [markdown]
# (2.) What function is used to rename files??

# %% [markdown]
# Ans:
#
# rename() method in Python is used to rename a file or directory.

# %% [markdown]
# # Q3

# %% [markdown]
# (3.) What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# Ans:
#
# * The send2trash functions will move a file or folder to the recycle bin.
# * shutil delete functions will permanently delete files and folders.

# %% [markdown]
# # Q4

# %% [markdown]
# (4.)ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

# %% [markdown]
# Ans:
#
# The zipfile.ZipFile() function is equivalent to the open() function; the first argument is the filename, and the second argument is the mode to open the ZIP file in (read, write, or append).

# %% [markdown]
# # Q5

# %% [markdown]
# (5.) Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %% [markdown]
# Ans:

# %%
import os, shutil
from os import path

def selectiveCopy(folder, extensions, destFolder):
    folder = os.path.abspath(folder)
    destFolder = os.path.abspath(destFolder)
    print('Looking in', folder, 'for files with extensions of', ', '.join(extensions))
    for foldername, subfolders, filenames in os.walk(folder):
        for filename in filenames:
            name, extension = os.path.splitext(filename)
            if extension in extensions:
                fileAbsPath = foldername + os.path.sep + filename
                print('Coping', fileAbsPath, 'to', destFolder)
                shutil.copy(fileAbsPath, destFolder)

extensions = ['.ipynb', '.docx']
folder = 'sfolder'
destFolder = 'dfolder'
selectiveCopy(folder, extensions, destFolder)
# Out:
# Looking in /home/anand/Downloads/sfolder for files with extensions of .ipynb, .docx
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-3.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-9.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-4.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Untitled1.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_9.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-1.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_5.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Untitled.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_10.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-7.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-5.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_6.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_7.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-10.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-8.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-2.ipynb to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/Assignment_8.docx to /home/anand/Downloads/dfolder
# Coping /home/anand/Downloads/sfolder/PythonBasicAssignment-6.ipynb to /home/anand/Downloads/dfolder

# %% [markdown]
# # Q1

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Ans:
#
# By using functions, we can avoid rewriting same logic/code again and again in a program. We can call functions any number of times in a program and from any place in a program. We can track a large program easily when it is divided into multiple functions.

# %% [markdown]
# # Q2

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# Ans:
#
# the code in a function run, when it's called.

# %% [markdown]
# # Q3

# %% [markdown]
# 3. What statement creates a function?

# %%
#A function is created with the def keyword. The statements in the block of the function must be indented.

def function():
    pass

# %% [markdown]
# # Q4

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# Ans:
#
# A function is a block of code that does a particular operation and returns a result. It usually accepts inputs as parameters and returns a result. The parameters are not mandatory.
#
# function call is to call (request by program) a predetermind function, by using the function name followed by parenthesis. parameter are depended on function code if mandotary or optional.

# %% [markdown]
# # Q5

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# Ans:
#
# In python program only one global scopes there untill the programm terminate.
#
# And When the execution of the function terminates (returns), the local variables are destroyed.the local scope only valid inside the function.

# %% [markdown]
# # Q6

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# When the execution of the function terminates (returns), the local variables are destroyed.

# %% [markdown]
# # Q7

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# Ans:
#
# In general, a function takes arguments (if any), performs some operations, and returns a value (or object). The value that a function returns to the caller is generally known as the function's return value.
#
# yes, its possible to have return value in an expression.

# %% [markdown]
# # Q8

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# Ans:
#
# the return value of a call to that function will be None.

# %% [markdown]
# # Q9

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# Ans:
#
# if you want to decalare function variable as global variable, you need to provide global keyword before the local variable of that function to make it global variable.

# %% [markdown]
# # Q10

# %% [markdown]
# 10. What is the data type of None?

# %% [markdown]
# Ans:
#
# None is special type of datatype in python. which means its does not hold any value now. but in future we can assign the value if needed

# %% [markdown]
# # Q11

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [markdown]
# Ans:
#
# it will imports a module named areallyourpetsnamederic.if that module not avialabe then it will return an error
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [markdown]
# # Q12

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# Ans:
#
# This function can be called with spam.bacon().

# %% [markdown]
# # Q13

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Ans:
#
# Place the line of code that might cause an error in a try clause.

# %% [markdown]
# # Q14

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# Ans:
#
# The code that could potentially cause an error goes in the try clause. -The code that executes if an error happens goes in the except clause.

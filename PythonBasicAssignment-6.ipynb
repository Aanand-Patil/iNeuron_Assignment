# %% [markdown]
# # Q1

# %% [markdown]
# 1. What are escape characters, and how do you use them?

# %% [markdown]
# Ans:
#
# To insert characters that are illegal in a string, use an escape character. An escape character is a backslash \ followed by the character you want to insert.

# %%
statement= " \"Iron-man\" is my favourite superhero in \"Avengers team\""
statement
# Out:
# ' "Iron-man" is my favourite superhero in "Avengers team"'

# %% [markdown]
# # Q2

# %% [markdown]
# 2. What do the escape characters n and t stand for?

# %% [markdown]
# Ans:
#
# escape character "\t" is stand for tab and escape character "\n" is stand for a newline,

# %% [markdown]
# # Q3

# %% [markdown]
# 3. What is the way to include backslash characters in a string?

# %% [markdown]
# Ans:
#
# The \ escape character will represent a backslash character.

# %% [markdown]
# # Q4

# %% [markdown]
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# Ans:
#
# The single quote in Howl's is fine because we have used double quotes to mark the beginning and end of the string.

# %% [markdown]
# # Q5

# %% [markdown]
# 5. How do you write a string of newlines if you don't want to use the n character?

# %% [markdown]
# Ans:
#
# You can write a string of newlines without use of n character by putting triple quote at the start and end of string.

# %% [markdown]
# # Q6

# %% [markdown]
# 6. What are the values of the given expressions?
# * 'Hello, world!'[1]
# * 'Hello, world!'[0:5]
# * 'Hello, world!'[:5]
# * 'Hello, world!'[3:]

# %% [markdown]
# Ans:

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# # Q7

# %% [markdown]
# 7. What are the values of the following expressions?
# * 'Hello'.upper()
# *  'Hello'.upper().isupper()
# * 'Hello'.upper().lower()

# %% [markdown]
# Ans:

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# # Q8

# %% [markdown]
# 8. What are the values of the following expressions?
#
# 'Remember, remember, the fifth of July.'.split()
#
# '-'.join('There can only one.'.split())

# %% [markdown]
# Ans:

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# # Q9

# %% [markdown]
# 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# Ans:
#
# * for right-justifying string:......rjust( )
# * for left-justifying strig:..........ljust( )
# * for centering string:.............center( )

# %% [markdown]
# # Q10

# %% [markdown]
# 10. What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# Ans:
#
# to remove whitespace characters from the start or end use lstrip() and rstrip().

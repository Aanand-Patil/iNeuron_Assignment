# %% [markdown]
# # Q1

# %% [markdown]
# 1. What does an empty dictionary's code look like?

# %% [markdown]
# Ans:
#
# empty dictionery's code two curly brackets  { }

# %% [markdown]
# # Q2

# %% [markdown]
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %% [markdown]
# Ans:
#
# d={'foo':42}

# %%
d={'foo':42}

# %% [markdown]
# # Q3

# %% [markdown]
# 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# Ans:
#
# A list is an ordered sequence of objects, whereas dictionaries are unordered sets. However, the main difference is that items in dictionaries are accessed via keys and not via their position.

# %% [markdown]
# # Q4

# %% [markdown]
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %% [markdown]
# Ans:
#
# if spam is {'bar':100} and if you try to access spam ['foo'] then you will get key error. becasue in spam dictionery not a key name of 'foo.'

# %%
spam={'bar': 100}
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 spam={'bar': 100}
# ----> 2 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# # Q5

# %% [markdown]
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %% [markdown]
# Ans:
#
# There is no difference. The in operator checks whether a value exists as a key in the dictionary.

# %%
spam={'cat':5}
print('cat'in spam.keys())
print('cat'in spam)
# Out:
# True
# True

# %%
print('cat'in spam.keys())==print('cat'in spam)
# Out:
# True
# True
# True

# %% [markdown]
# # Q6

# %% [markdown]
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# Ans:
#
# 'cat' in spam: the in operator checks whether a value exits as a key in the dictionary.
#
# 'cat' in spam.values() : the in operator checks whether a value exits as a value in the dictionary.

# %% [markdown]
# # Q7

# %% [markdown]
# 7. What is a shortcut for the following code?
#
# if 'color' not in spam:
#
# spam['color'] = 'black'

# %% [markdown]
# Ans

# %%
spam={}
spam.setdefault('color', 'black')
# Out:
# 'black'

# %% [markdown]
# # Q8

# %% [markdown]
# 8. How do you "pretty print" dictionary values using which module and function?

# %% [markdown]
# Ans:
#
# Within the pprint module there is a function with the same name pprint(), which is the function used to pretty-print the given string or object.
#
# pprint.pprint()
